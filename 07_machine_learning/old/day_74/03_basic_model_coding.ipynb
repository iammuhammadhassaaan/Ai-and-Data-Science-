# %% [markdown]
# # **Machine Learning** _Day 74_
# ##### Name: Muhammad Hassaan
# ##### Date: April 15, 2024
# ##### Email: muhammadhassaan7896@gmail.com

# %% [markdown]
# ---
# # **Model Notebook for coding in sklearn**
# ---

# %%
# import libraries
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler, LabelEncoder

# %%
# imoprt the data
df = sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# separate the features X and the target/labels y
X = df[['total_bill']]
y = df['tip']

# %%
# train test split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8)

# %%
# # preprocess the data
# scalar = StandardScaler()
# X_train = scalar.fit_transform(X_train)
# X_test = scalar.transform(X_test)

# %%
# call the model 
model = LinearRegression()

# %%
# build the model 
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# predict the model 
y_pred = model.predict(X_test)

# %%
model.predict([[15]])
# Out:
# c:\Users\muham\miniconda3\envs\ml_python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([2.49613075])

# %%
# evaluation the model 
from sklearn.metrics import mean_squared_error, r2_score
print("Mean squared error:", mean_squared_error(y_test, y_pred))
print('R2:', r2_score(y_test, y_pred))
# Out:
# Mean squared error: 0.7456267212482
# R2: 0.3942577153976451

# %%
# plot the results
plt.scatter(X_test, y_test,  color='black')
plt.plot(X_test, y_pred, color='blue', linewidth=3)

plt.xticks(())

plt.yticks(())

plt.show()

# %%
model.predict([[30]])
# Out:
# c:\Users\muham\miniconda3\envs\ml_python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([4.10427056])

# %%
# save the model 
import pickle
pickle.dump(model, open('../saved_models/model_01.pkl', 'wb'))

# %%
# load the model
import pickle 
model_load = pickle.load(open('../saved_models/model_01.pkl', 'rb'))

# %%
model_load.predict([[15]])
# Out:
# c:\Users\muham\miniconda3\envs\ml_python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([2.49613075])
